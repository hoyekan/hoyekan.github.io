# %% [markdown]
# ## Attenuation Coefficient in Wave Propagation
#
# The attenuation coefficient in wave propagation is directly related to the __imaginary part of the complex wavenumber__, which can be derived from the complex velocity.
#
# ### 1. The Complex Wavenumber and Complex Velocity
#
# In a lossy medium, a one-dimensional propagating wave can be described by:
#
# $$
# p(x, t) = p_0 e^{i(\omega t - kx)}
# $$
#
# where:
# - $ p $ is the wave field (e.g., pressure for sound, electric field for EM waves)
# - $ \omega $ is the angular frequency
# - $ k $ is the **wavenumber**
#
# In a dissipative medium, the wavenumber becomes a **complex number**:
#
# $$
# k = k_r - i \alpha
# $$
#
# where:
# - $ k_r $ is the **real part** of the wavenumber, related to the phase velocity
# - $ \alpha $ is the **attenuation coefficient** (a positive real number), responsible for the exponential decay of the wave's amplitude
#
# Substituting this into the wave equation gives:
#
# $$
# p(x, t) = p_0 e^{i(\omega t - (k_r - i\alpha)x)} = p_0 e^{i(\omega t - k_r x)} \cdot e^{-\alpha x}
# $$
#
# The term $ e^{-\alpha x} $ clearly shows the exponential amplitude decay.
#
# The **complex velocity**, $ c^* $, is defined as:
#
# $$
# c^* = \frac{\omega}{k}
# $$
#
# ### 2. The Formula for the Attenuation Coefficient
#
# We can rearrange the definition of the complex velocity to solve for $ k $:
#
# $$
# k = \frac{\omega}{c^*}
# $$
#
# Since $ k $ is complex ($ k = k_r - i\alpha $), $ c^* $ must also be complex. Let's express the complex velocity in terms of its real and imaginary parts. The standard convention is:
#
# $$
# c^* = c_r + i c_i
# $$
#
# where $ c_i > 0 $ for a dissipative medium: with $k = k_r - i\alpha$ and $c^* = \omega/k$, one gets $\alpha = \omega c_i/|c^*|^2$, so $\alpha>0$ requires $c_i>0$.
#
# Now, let's find the formula for $ \alpha $:
#
# $$
# k = k_r - i\alpha = \frac{\omega}{c^*} = \frac{\omega}{c_r + i c_i}
# $$
#
# To separate the real and imaginary parts, we multiply the numerator and denominator by the complex conjugate of the denominator:
#
# $$
# k_r - i\alpha = \frac{\omega}{(c_r + i c_i)} \cdot \frac{(c_r - i c_i)}{(c_r - i c_i)} = \frac{\omega (c_r - i c_i)}{c_r^2 + c_i^2}
# $$
#
# Now, equate the real and imaginary parts from both sides:
#
# - **Real Part:** $ k_r = \dfrac{\omega c_r}{c_r^2 + c_i^2} $
# - **Imaginary Part:** $ -\alpha = \dfrac{-\omega c_i}{c_r^2 + c_i^2} $
#
# From the imaginary part, we get the primary formula:
#
# $$
# \boxed{\alpha = \frac{\omega \, (c_i)}{c_r^2 + c_i^2}}
# $$
#
# $$
# \alpha = \frac{\omega\,\text{Im}(c)}{|c|^2} \approx \frac{\omega c_i}{c_r^2} \quad \text{for small } c_i
# $$
#
# For most geophysical problems, $c_i \ll c_r$, so this is valid.
#
# This is the general formula for the attenuation coefficient in terms of the complex velocity $ c^* = c_r + i c_i $
#
# ---
#
# ### 3. The "Quality Factor" Convention
#
# In many fields like geophysics and elastodynamics, a different representation is used. The complex velocity is expressed in terms of a **quality factor**, $ Q $, which is a dimensionless measure of attenuation (low $ Q $ means high attenuation).
#
# For small attenuation ($ Q \gg 1 $), the standard formulation is:
#
# $$
# \frac{1}{c^*} \approx \frac{1}{c} \left( 1 - \frac{i}{2Q} \right)
# $$
#
# where $ c $ is the real-valued phase velocity at low loss.
#
# Starting from the wavenumber:
#
# $$
# k = \frac{\omega}{c^*} \approx \frac{\omega}{c} \left( 1 - \frac{i}{2Q} \right) = \frac{\omega}{c} - i \frac{\omega}{2cQ}
# $$
#
# Comparing this to $ k = k_r - i\alpha $, we immediately identify:
#
# $$
# \boxed{\alpha \approx \frac{\omega}{2cQ}}
# $$
#
# This is a very common and useful approximation that clearly shows attenuation increases linearly with frequency for a constant $ Q $, which is observed in many real materials like the Earth's crust.
#
# This is the standard high-Q attenuation model:
#
# * attenuation ∝ frequency
# * phase velocity assumed constant
# * causal dispersion ignored (valid only for large (Q))
# * weak-attenuation models (high Q, no dispersion).
#
# ### Summary
#
# | Context | Formula for Attenuation Coefficient $$ \alpha $$ |
# | :--- | :--- |
# | **General Complex Velocity**<br>($ c^* = c_r + i c_i $) | $ \alpha = \dfrac{\omega \, c_i}{c_r^2 + c_i^2} $ |
# | **Low-Loss "Q" Approximation**<br>($ Q \gg 1 $) | $ \alpha \approx \dfrac{\omega}{2cQ} $ |
#
# The choice of formula depends on how the properties of your lossy medium are characterized—whether by a direct complex velocity or by a quality factor ($ Q $).

# %% [markdown]
# ### Model 1

# %%
from love_engine import *

MODEL_ID = 1
out = run_dispersion(model_id=MODEL_ID, n_modes=7,
                     freq_min=0.1, freq_max=80.0, n_freq=200,
                     f_ref=1.0)     # f_ref=None -> treat Layer.beta as unrelaxed
plot_results(*out, MODEL_ID)
print("\nDone.")
# Out:
# GMB fit: band=(0.025, 160.0) Hz, f_ref=1.0
#   target Q |  realised Q at 0.1Hz 2.83Hz 80Hz
#       18.0 |    17.95    17.99    18.07   [negative weight present -- passivity checked below]
#       30.0 |    29.91    29.98    30.11   [negative weight present -- passivity checked below]
#       42.0 |    41.87    41.98    42.15   [negative weight present -- passivity checked below]
#       50.0 |    49.85    49.98    50.18   [negative weight present -- passivity checked below]
# self_test passed: det(G)=1, half-space decays, Im(mu)>0, Q on target, single-layer D = closed form.
# ==============================================================================
# f =   0.100 Hz | 0 mode(s) | c = [] m/s | alpha = [] x 1e-6 /m
# f =   6.524 Hz | 1 mode(s) | c = [335.3] m/s | alpha = [4132.52] x 1e-6 /m
# f =  12.948 Hz | 2 mode(s) | c = [229.3, 495.8] m/s | alpha = [12235.09, 3282.22] x 1e-6 /m
# f =  19.372 Hz | 2 mode(s) | c = [209.1, 391.6] m/s | alpha = [18417.66, 10150.44] x 1e-6 /m
# f =  25.796 Hz | 3 mode(s) | c = [202.1, 328.5, 501.0] m/s | alpha = [24285.17, 17178.76, 6819.34] x 1e-6 /m
# f =  32.221 Hz | 3 mode(s) | c = [199.1, 286.7, 421.2] m/s | alpha = [30113.92, 28626.01, 19670.29] x 1e-6 /m
# f =  38.645 Hz | 4 mode(s) | c = [197.6, 256.6, 363.1, 487.2] m/s | alpha = [35862.66, 39121.46, 22863.13, 12960.59] x 1e-6 /m
# f =  45.069 Hz | 4 mode(s) | c = [196.8, 238.1, 335.3, 440.8] m/s | alpha = [41496.21, 46099.23, 26418.59, 21670.90] x 1e-6 /m
# f =  51.493 Hz | 5 mode(s) | c = [196.4, 226.9, 314.4, 389.2, 489.2] m/s | alpha = [47037.44, 51742.77, 37245.04, 35157.05, 20970.94] x 1e-6 /m
# f =  57.917 Hz | 5 mode(s) | c = [196.2, 219.7, 291.1, 353.4, 445.5] m/s | alpha = [52540.16, 57022.48, 55097.85, 34812.05, 29402.89] x 1e-6 /m
# f =  64.341 Hz | 6 mode(s) | c = [196.1, 214.8, 269.6, 336.4, 405.9, 484.7] m/s | alpha = [58059.13, 62252.62, 67517.37, 33678.82, 39406.86, 21610.10] x 1e-6 /m
# f =  70.765 Hz | 6 mode(s) | c = [196.1, 211.3, 253.8, 325.4, 372.7, 458.5] m/s | alpha = [63633.55, 67545.95, 74924.68, 39613.31, 47935.12, 29449.70] x 1e-6 /m
# f =  77.189 Hz | 7 mode(s) | c = [196.1, 208.8, 242.5, 313.0, 347.9, 422.4, 478.3] m/s | alpha = [69282.06, 72940.20, 80671.89, 58921.23, 49005.63, 52726.75, 31425.56] x 1e-6 /m
# ==============================================================================
# Done.
# C:\Users\Ahmed\Downloads\Dispersion_and_Attenuation_of_Love_Waves_in_an_Isotropic_Viscoelastic_Layers.-main\Love Waves\love_engine.py:416: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### Model 3 - Deep Crustal Model

# %%
from love_engine import *

MODEL_ID = 3
out = run_dispersion(model_id=MODEL_ID, n_modes=8,
                     freq_min=0.01, freq_max=0.5, n_freq=120,
                     f_ref=1.0)
plot_results(*out, MODEL_ID)
print("\nDone.")
# Out:
# GMB fit: band=(0.005, 1.0) Hz, f_ref=1.0
#   target Q |  realised Q at 0.01Hz 0.0707Hz 0.5Hz
#      250.0 |   250.85   249.32   250.86   [negative weight present -- passivity checked below]
#      330.0 |   331.12   329.11   331.13   [negative weight present -- passivity checked below]
#      360.0 |   361.23   359.03   361.23   [negative weight present -- passivity checked below]
#      400.0 |   401.36   398.92   401.37   [negative weight present -- passivity checked below]
#      430.0 |   431.47   428.84   431.47   [negative weight present -- passivity checked below]
#      450.0 |   451.53   448.78   451.54   [negative weight present -- passivity checked below]
# self_test passed: det(G)=1, half-space decays, Im(mu)>0, Q on target, single-layer D = closed form.
# ==============================================================================
# f =   0.010 Hz | 1 mode(s) | c = [4373.3] m/s | alpha = [0.02] x 1e-6 /m
# f =   0.051 Hz | 1 mode(s) | c = [3185.4] m/s | alpha = [0.21] x 1e-6 /m
# f =   0.092 Hz | 2 mode(s) | c = [2814.7, 4081.6] m/s | alpha = [0.45, 0.27] x 1e-6 /m
# f =   0.134 Hz | 3 mode(s) | c = [2675.5, 3687.6, 4375.7] m/s | alpha = [0.68, 0.44, 0.33] x 1e-6 /m
# f =   0.175 Hz | 4 mode(s) | c = [2610.3, 3461.1, 4028.3, 4490.0] m/s | alpha = [0.89, 0.65, 0.53, 0.32] x 1e-6 /m
# f =   0.216 Hz | 4 mode(s) | c = [2575.2, 3274.9, 3773.5, 4246.0] m/s | alpha = [1.11, 0.95, 0.72, 0.61] x 1e-6 /m
# f =   0.257 Hz | 5 mode(s) | c = [2554.2, 3101.3, 3605.9, 4000.3, 4366.0] m/s | alpha = [1.32, 1.29, 0.87, 0.80, 0.66] x 1e-6 /m
# f =   0.298 Hz | 6 mode(s) | c = [2540.8, 2960.4, 3497.9, 3830.6, 4173.7, 4452.5] m/s | alpha = [1.52, 1.58, 1.01, 0.95, 0.86, 0.71] x 1e-6 /m
# f =   0.339 Hz | 6 mode(s) | c = [2531.7, 2857.8, 3416.6, 3700.5, 3986.9, 4280.4] m/s | alpha = [1.72, 1.81, 1.21, 1.16, 1.11, 0.90] x 1e-6 /m
# f =   0.381 Hz | 7 mode(s) | c = [2525.3, 2784.5, 3332.5, 3578.7, 3838.2, 4137.8, 4362.4] m/s | alpha = [1.92, 2.03, 1.56, 1.40, 1.21, 1.10, 1.06] x 1e-6 /m
# f =   0.422 Hz | 8 mode(s) | c = [2520.6, 2731.2, 3226.6, 3485.3, 3744.2, 3989.9, 4213.1, 4434.7] m/s | alpha = [2.13, 2.24, 2.05, 1.48, 1.29, 1.41, 1.13, 1.02] x 1e-6 /m
# f =   0.463 Hz | 8 mode(s) | c = [2517.1, 2691.5, 3113.9, 3428.8, 3671.9, 3854.7, 4109.5, 4293.7] m/s | alpha = [2.33, 2.44, 2.46, 1.54, 1.49, 1.57, 1.29, 1.33] x 1e-6 /m
# ==============================================================================
# Done.

# %% [markdown]
# ### Model 4 - Near Surface Model

# %%
from love_engine import *

# Model 4 layers are 3-6 m thick.  Below ~0.5 Hz the fundamental is
# numerically indistinguishable from the half-space velocity (the trapped
# mode merges into beta_{N+1}), so the sweep starts there rather than at
# 0.01 Hz.  Scanning below that returned LEAKY roots in the old code,
# because its window used the table beta instead of Re(beta_j(omega)).
out = run_dispersion(model_id=4, n_modes=9,
                     freq_min=0.5, freq_max=80.0, n_freq=200, f_ref=1.0)
plot_results_full(*out, 4)
print("\nDone.")
# Out:
# GMB fit: band=(0.025, 160.0) Hz, f_ref=1.0
#   target Q |  realised Q at 0.5Hz 6.32Hz 80Hz
#       19.0 |    19.01    19.03    19.07   [negative weight present -- passivity checked below]
#       28.0 |    28.02    28.04    28.10   [negative weight present -- passivity checked below]
#       32.0 |    32.02    32.05    32.12   [negative weight present -- passivity checked below]
#       46.0 |    46.03    46.07    46.17   [negative weight present -- passivity checked below]
#       63.0 |    63.03    63.09    63.23   [negative weight present -- passivity checked below]
#       75.0 |    75.04    75.11    75.27   [negative weight present -- passivity checked below]
# self_test passed: det(G)=1, half-space decays, Im(mu)>0, Q on target, single-layer D = closed form.
# ==============================================================================
# f =   0.500 Hz | 0 mode(s) | c = [] m/s | alpha = [] x 1e-6 /m
# f =   6.892 Hz | 1 mode(s) | c = [380.4] m/s | alpha = [3258.01] x 1e-6 /m
# f =  13.284 Hz | 2 mode(s) | c = [285.7, 664.3] m/s | alpha = [7792.61, 2969.61] x 1e-6 /m
# f =  19.676 Hz | 3 mode(s) | c = [254.0, 419.4, 731.3] m/s | alpha = [14880.92, 10496.06, 4267.22] x 1e-6 /m
# f =  26.068 Hz | 3 mode(s) | c = [234.9, 353.4, 549.5] m/s | alpha = [21767.56, 11480.58, 9826.00] x 1e-6 /m
# f =  32.460 Hz | 4 mode(s) | c = [224.5, 333.3, 445.2, 664.1] m/s | alpha = [27636.23, 13015.10, 15400.08, 9927.24] x 1e-6 /m
# f =  38.852 Hz | 5 mode(s) | c = [218.6, 323.9, 387.8, 548.5, 754.6] m/s | alpha = [33030.44, 15149.84, 19729.78, 13525.81, 5033.03] x 1e-6 /m
# f =  45.244 Hz | 5 mode(s) | c = [215.1, 318.1, 354.2, 473.8, 639.2] m/s | alpha = [38171.83, 17846.94, 24574.84, 21070.88, 18238.98] x 1e-6 /m
# f =  51.636 Hz | 6 mode(s) | c = [212.9, 313.1, 330.0, 414.7, 538.4, 707.1] m/s | alpha = [43169.72, 22961.61, 30761.59, 28026.70, 20725.49, 13081.32] x 1e-6 /m
# f =  58.028 Hz | 7 mode(s) | c = [211.4, 301.4, 315.9, 379.4, 478.1, 592.5, 728.7] m/s | alpha = [48106.80, 42824.82, 25303.03, 28619.92, 28689.08, 27720.53, 14275.63] x 1e-6 /m
# f =  64.420 Hz | 7 mode(s) | c = [210.4, 283.2, 312.0, 360.7, 428.5, 524.6, 658.9] m/s | alpha = [53046.65, 55940.47, 25050.87, 28032.40, 35110.87, 23624.05, 19572.94] x 1e-6 /m
# f =  70.812 Hz | 8 mode(s) | c = [209.6, 268.2, 309.7, 350.0, 395.5, 485.5, 578.5, 701.3] m/s | alpha = [58030.95, 64050.63, 27125.99, 28591.55, 37112.53, 28819.13, 29027.98, 16821.60] x 1e-6 /m
# f =  77.204 Hz | 9 mode(s) | c = [209.1, 257.0, 308.1, 342.9, 373.7, 448.1, 527.6, 645.9, 752.3] m/s | alpha = [63079.53, 70311.09, 29523.23, 30331.24, 39557.29, 38554.84, 26196.92, 23216.35, 15263.50] x 1e-6 /m
# ==============================================================================
# C:\Users\Ahmed\Downloads\Dispersion_and_Attenuation_of_Love_Waves_in_an_Isotropic_Viscoelastic_Layers.-main\Love Waves\love_engine.py:444: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# C:\Users\Ahmed\Downloads\Dispersion_and_Attenuation_of_Love_Waves_in_an_Isotropic_Viscoelastic_Layers.-main\Love Waves\love_engine.py:458: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# Done.
# C:\Users\Ahmed\Downloads\Dispersion_and_Attenuation_of_Love_Waves_in_an_Isotropic_Viscoelastic_Layers.-main\Love Waves\love_engine.py:473: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ##### Implementing Three Attenuation Methods, Eigenfunction Visualization, Quality Factor Q(ω) Extraction, and  Old vs New Direct Comparison

# %%
from love_engine import *

# Model 1's layers total 15 m.  Below ~2 Hz its fundamental is numerically
# indistinguishable from beta_{N+1}; the original 0.01-0.5 Hz sweep found
# only LEAKY roots (Re(c) > Re(beta_{N+1})), admitted because the search
# window used the table beta rather than Re(beta_j(omega)).
MODEL_ID = 1
freq, c_ph, a_simp, a_pert, a_exact, Q_L, layers, halfspace, bank = \
    run_all_methods(model_id=MODEL_ID, n_modes=6,
                    freq_min=2.0, freq_max=60.0, n_freq=80)

n_found = int(np.isfinite(c_ph).any(axis=1).sum())
print(f"\nTrapped modes found: {n_found}")
if n_found == 0:
    raise SystemExit("No trapped Love modes in this band.")

print("\n1. attenuation, three methods ...")
plot_method_comparison(freq, a_simp, a_pert, a_exact, MODEL_ID)
print("2. eigenfunctions ...")
plot_eigenfunctions(freq, c_ph, layers, halfspace, bank, MODEL_ID)
print("3. Q(omega) of the mode ...")
plot_quality_factor(freq, Q_L, layers, halfspace, MODEL_ID)
print("\nDone.")
# Out:
# GMB fit: band=(0.025, 120.0) Hz, f_ref=1.0
#   target Q |  realised Q at 2Hz 11Hz 60Hz
#       18.0 |    18.01    17.98    18.07   [negative weight present -- passivity checked below]
#       30.0 |    30.02    29.96    30.11   [negative weight present -- passivity checked below]
#       42.0 |    42.02    41.95    42.16   [negative weight present -- passivity checked below]
#       50.0 |    50.03    49.94    50.18   [negative weight present -- passivity checked below]
# self_test passed: det(G)=1, half-space decays, Im(mu)>0, Q on target, single-layer D = closed form.
# ==============================================================================
# f =   2.00 Hz -> 1 mode(s)
# f =   7.87 Hz -> 1 mode(s)
# f =  13.75 Hz -> 2 mode(s)
# f =  19.62 Hz -> 2 mode(s)
# f =  25.49 Hz -> 3 mode(s)
# f =  31.37 Hz -> 3 mode(s)
# f =  37.24 Hz -> 4 mode(s)
# f =  43.11 Hz -> 4 mode(s)
# f =  48.99 Hz -> 5 mode(s)
# f =  54.86 Hz -> 5 mode(s)
# ==============================================================================
#
# Trapped modes found: 6
#
# 1. attenuation, three methods ...
# C:\Users\Ahmed\Downloads\Dispersion_and_Attenuation_of_Love_Waves_in_an_Isotropic_Viscoelastic_Layers.-main\Love Waves\love_engine.py:639: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# 2. eigenfunctions ...
# worst free-surface residual |sigma_yz(0)| / (|mu1 nu1||u(0)|) = 9.04e-15
# C:\Users\Ahmed\Downloads\Dispersion_and_Attenuation_of_Love_Waves_in_an_Isotropic_Viscoelastic_Layers.-main\Love Waves\love_engine.py:688: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# 3. Q(omega) of the mode ...
# Done.
# C:\Users\Ahmed\Downloads\Dispersion_and_Attenuation_of_Love_Waves_in_an_Isotropic_Viscoelastic_Layers.-main\Love Waves\love_engine.py:716: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
